# %%
import pandas as pd
import re

# %%
# Revisar http://files.grouplens.org/datasets/movielens/ml-latest-README.html

# %%
movies = pd.read_csv("movies.csv",index_col=0)
ratings = pd.read_csv("ratings.csv")
ratings=ratings.rename(columns={'timestamp':'TimeRating'})
#links = pd.read_csv("links.csv")#imbdld es tag tmbdld es tiemstamp, tiempo que lo vio
#genome_scores=pd.read_csv("genome-scores.csv")
#tags = pd.read_csv("tags.csv")
#tags=tags.rename(columns={'timestamp':'TimeTag'})
#genome_tags=pd.read_csv("genome-tags.csv",index_col=0)

# %%
def Año(txt): 
    x=re.findall(r"[(]\d+[)]", txt)
    if len(x)>=1:
        return int(x[-1][1:5])
    else:
        return None

movies['year']=movies['title'].apply(Año)
movies['year'].unique()
# Out:
# C:\Users\jplop\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# array([1995, 1994, 1996, 1976, 1992, 1988, 1967, 1993, 1964, 1977, 1965,
#        1982, 1985, 1990, 1991, 1989, 1937, 1940, 1969, 1981, 1973, 1970,
#        1960, 1955, 1959, 1968, 1980, 1975, 1986, 1948, 1943, 1950, 1946,
#        1987, 1997, 1974, 1956, 1958, 1949, 1972, 1998, 1933, 1952, 1951,
#        1957, 1961, 1954, 1934, 1944, 1963, 1942, 1941, 1953, 1939, 1947,
#        1945, 1938, 1935, 1936, 1926, 1932, 1979, 1971, 1978, 1966, 1962,
#        1983, 1984, 1931, 1922, 1999, 1927, 1929, 1930, 1928, 1925, 1914,
#        2000, 1919, 1923, 1920, 1918, 1921, 2001, 1924, 2002, 2003, 1915,
# ...

# %%
movies
# Out:
#                                            title  \
# movieId
# 1                               Toy Story (1995)
# 2                                 Jumanji (1995)
# 3                        Grumpier Old Men (1995)
# 4                       Waiting to Exhale (1995)
# 5             Father of the Bride Part II (1995)
# ...                                          ...
# 193876                   The Great Glinka (1946)
# 193878   Les tribulations d'une caissière (2011)
# 193880                  Her Name Was Mumu (2016)
# 193882                              Flora (2017)
# 193886                               Leal (2018)
#
#                                               genres    year
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 2                         Adventure|Children|Fantasy  1995.0
# 3                                     Comedy|Romance  1995.0
# 4                               Comedy|Drama|Romance  1995.0
# ...

# %%
movies=movies[movies['year']>0]
movies
# Out:
#                                            title  \
# movieId
# 1                               Toy Story (1995)
# 2                                 Jumanji (1995)
# 3                        Grumpier Old Men (1995)
# 4                       Waiting to Exhale (1995)
# 5             Father of the Bride Part II (1995)
# ...                                          ...
# 193876                   The Great Glinka (1946)
# 193878   Les tribulations d'une caissière (2011)
# 193880                  Her Name Was Mumu (2016)
# 193882                              Flora (2017)
# 193886                               Leal (2018)
#
#                                               genres    year
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 2                         Adventure|Children|Fantasy  1995.0
# 3                                     Comedy|Romance  1995.0
# 4                               Comedy|Drama|Romance  1995.0
# ...

# %%
movies['Genre'] = movies['genres'].apply(lambda x: x.split('|'))
movies['year'] =movies['title'].str.extract('.*\((.*)\).*',expand = False)
lista=[]
for a in movies['Genre']:
  lista=lista+a
generos=list(set(lista))
for b in generos:
  movies[b]=0
  for a in movies.index:
    if b in movies['Genre'][a]:
      movies[b][a]=1
movies.drop(['Genre','genres'],axis=1,inplace=True)
movies.head()
# Out:
# C:\Users\jplop\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df=pd.merge(pd.merge(movies,ratings,how='inner',on='movieId'),tags,how='left',on=['movieId','userId'])
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#                                                Genre  year  Drama  Romance  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995      0        0
# 1  [Adventure, Animation, Children, Comedy, Fantasy]  1995      0        0
# 2  [Adventure, Animation, Children, Comedy, Fantasy]  1995      0        0
# 3  [Adventure, Animation, Children, Comedy, Fantasy]  1995      0        0
# 4  [Adventure, Animation, Children, Comedy, Fantasy]  1995      0        0
#
# ...

# %%
df2=pd.merge(genome_scores,genome_tags,how='inner',on='tagId')
df2.head()
# Out:
#    movieId  tagId  relevance  tag
# 0        1      1    0.02900  007
# 1        2      1    0.03625  007
# 2        3      1    0.04150  007
# 3        4      1    0.03350  007
# 4        5      1    0.04050  007

# %%
MoviesPredict=pd.merge(df2,df,how='right',on=['movieId','tag'])
MoviesPredict.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-f6671a9d98d7> in <module>
# ----> 1 MoviesPredict=pd.merge(df2,df,how='right',on=['movieId','tag'])
#       2 MoviesPredict['Genre'] = MoviesPredict['genres'].apply(lambda x: x.split('|'))
#       3 MoviesPredict.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     679             axes=[llabels.append(rlabels), join_index],
#     680             concat_axis=0,
# --> 681             copy=self.copy,
#     682         )
#     683
#
# ...

# %%
MoviesPredict.count()

# %%
MoviesPredict['title'].unique()

# %% [markdown]
# similitud del coseno
# als
# 2 más
# Pyspark ALS**
# pyspark --> ALS UNO SI O SI
# CREAR METRICAS PARA COMPARAR RECOMENDACIONES
# intento + intento de mejora (modificart hiperparametros, cambiar metricas, etc.)
# Se puede exporrtar los modelos a archivos, asi despues le hago pruebas
# https://cloud.google.com/ai-platform/prediction/docs/exporting-for-prediction

# %%
RatUser=ratings.groupby(by='userId').mean()['rating'].sort_values(ascending=True)
RatUser.head()
# Out:
# userId
# 246381    0.5
# 117977    0.5
# 163134    0.5
# 61279     0.5
# 280246    0.5
# Name: rating, dtype: float64

# %%
ratings
# Out:
#           userId  movieId  rating  TimeRating
# 0              1      307     3.5  1256677221
# 1              1      481     3.5  1256677456
# 2              1     1091     1.5  1256677471
# 3              1     1257     4.5  1256677460
# 4              1     1449     4.5  1256677264
# ...          ...      ...     ...         ...
# 27753439  283228     8542     4.5  1379882795
# 27753440  283228     8712     4.5  1379882751
# 27753441  283228    34405     4.5  1379882889
# 27753442  283228    44761     4.5  1354159524
# 27753443  283228    54286     4.5  1354159718
#
# [27753444 rows x 4 columns]
